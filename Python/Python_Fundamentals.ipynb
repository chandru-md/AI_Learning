# %%
print("Hello World")
# Out:
# Hello World

# %%
#level-1

# %%
## Number Guessing game

# %%
secret_number = 52

guessing_number = int(input("Enter your guess number:"))

if secret_number == guessing_number:
    print("You win")
else:
    print("You lose")
# Out:
# Enter your guess number: 54
# You lose

# %%
secret_number = 90    #variable ---- integer format

# %%
guessing_number = int(input("Enter your guess number:"))   #input function ---- get input form user
# Out:
# Enter your guess number: 45

# %%
if secret_number == guessing_number:   #conditional statement ----- if-else
    print("You win")
else:
    print("You lose")
# Out:
# You lose

# %%
print("hello")
# Out:
# hello

# %%
name = input("enter your name: ")  ##string format
# Out:
# enter your name:  Chandru

# %%
# == equal to -------operator

# %%
secret_number = 52

guessing_number = int(input("Enter your guess number:"))

if secret_number == guessing_number:
    print("You win")
else:
    print("You lose")
# Out:
# Enter your guess number: 45
# You lose

# %%
secret_number = 52

guessing_number = int(input("Enter your guess number:"))

if secret_number == guessing_number:
    print("You win")
else:
    print("You lose")
# Out:
# Enter your guess number: 52
# You win

# %%
'''
int
float
str
boolean
'''
# Out:
# '\nint\nfloat\nstr\nboolean\n'

# %%
guessing_number
# Out:
# 52

# %%
str(guessing_number)
# Out:
# '52'

# %%
#typecasting --- converting one data type into another data type called typecasting

# %%
#level 2

# %%
secret_number = 85

for i in range(0,7):
    
    guessing_number = int(input("Enter your guess number:"))
    
    if secret_number == guessing_number:
        print("You win")
    else:
        print("You lose")
# Out:
# Enter your guess number: 45
# You lose
# Enter your guess number: 85
# You win
# Enter your guess number: 65
# You lose
# Enter your guess number: 74
# You lose
# Enter your guess number: 12
# You lose
# Enter your guess number: 35
# You lose
# Enter your guess number: 65
# You lose

# %%
secret_number = 85

for i in range(0,7):
    
    guessing_number = int(input("Enter your guess number:"))
    
    if secret_number == guessing_number:
        print("You win")
        break
    else:
        print("You lose")
# Out:
# Enter your guess number: 74
# You lose
# Enter your guess number: 95
# You lose
# Enter your guess number: 45
# You lose
# Enter your guess number: 85
# You win

# %%
#break

# %%
secret_number = 85

while True:
    
    guessing_number = int(input("Enter your guess number:"))
    
    if secret_number == guessing_number:
        print("You win")
        break
    else:
        print("You lose")
# Out:
# Enter your guess number: 74
# You lose
# Enter your guess number: 11
# You lose
# Enter your guess number: 22
# You lose
# Enter your guess number: 33
# You lose
# Enter your guess number: 65
# You lose
# Enter your guess number: 45
# You lose
# Enter your guess number: 85
# You win

# %%
# how do you choose b/w for loop and while loop

"""
if the iteration count is defined in advance I'll go with For loop.
if the loop depends on a runtime condition I'll go with while loop.
"""
# Out:
# "\nif the iteration count is defined in advance I'll go with For loop.\nif the loop depends on a runtime condition I'll go with while loop.\n"

# %%
#level - 3

# %%
secret_number = 85

while True:
    
    guessing_number = int(input("Enter your guess number:"))
    
    if secret_number == guessing_number:
        print("You win")
        break
    else:
        print("You lose")
# Out:
# Enter your guess number: 44
# You lose
# Enter your guess number: 11
# You lose
# Enter your guess number: 22
# You lose
# Enter your guess number: 33
# You lose
# Enter your guess number: 55
# You lose
# Enter your guess number: 44
# You lose
# Enter your guess number: 74
# You lose
# Enter your guess number: 96
# You lose
# Enter your guess number: 85
# You win

# %%
print("Welcome to number guessing name!!!")
print("Guess the number between 1-100")

secret_number = 85

for i in range(1,8):
    
    guessing_number = int(input("Enter your guess number:"))
    
    if guessing_number  < 1 or guessing_number > 100: 
        print("Invalid number. please enter number between 1-100")
    elif guessing_number < secret_number:
        print("Your number is lesser")
    elif guessing_number > secret_number:
        print("Your number is higher")
    else:
        print("Your guessed number is right, congrats.")
        print(f"Congradulations you guessed number is {guessing_number} in {i} iteration")
        break
# Out:
# Welcome to number guessing name!!!
# Guess the number between 1-100
# Enter your guess number: 858
# Invalid number. please enter number between 1-100
# Enter your guess number: 55
# Your number is lesser
# Enter your guess number: 2
# Your number is lesser
# Enter your guess number: 3
# Your number is lesser
# Enter your guess number: 1
# Your number is lesser
# Enter your guess number: 4
# Your number is lesser
# Enter your guess number: 85
# Your guessed number is right, congrats.
# Congradulations you guessed number is 85 in 7 iteration

# %%
print("Welcome to number guessing name!!!")
print("Guess the number between 1-100")

secret_number = 85

for i in range(1,8):
    
    guessing_number = int(input("Enter your guess number:"))
    
    if guessing_number  < 1 or guessing_number > 100: 
        print("Invalid number. please enter number between 1-100")
    elif guessing_number < secret_number:
        print("Your number is lesser")
    elif guessing_number > secret_number:
        print("Your number is higher")
    else:
        
        print("Your guessed number is right, congrats.")
        break

if secret_number == guessing_number:
    print(f"Congradulations you guessed number is {guessing_number} in {i} iteration")
else:
    print("Sorry!!! you trials is exceeded. Try Again.")
# Out:
# Welcome to number guessing name!!!
# Guess the number between 1-100
# Enter your guess number: 44
# Your number is lesser
# Enter your guess number: 85
# Your guessed number is right, congrats.
# Congradulations you guessed number is 85 in 2 iteration

# %%
import random

# %%
random.randint(0,10)
# Out:
# 4

# %%
import random

print("Welcome to number guessing name!!!")
print("Guess the number between 1-100")

secret_number = random.randint(1,100)

for i in range(1,8):
    
    guessing_number = int(input("Enter your guess number:"))
    
    if guessing_number  < 1 or guessing_number > 100: 
        print("Invalid number. please enter number between 1-100")
    elif guessing_number < secret_number:
        print("Your number is lesser")
    elif guessing_number > secret_number:
        print("Your number is higher")
    else:
        print("Your guessed number is right, congrats.")
        break

if secret_number == guessing_number:
    print(f"Congradulations you guessed number is {guessing_number} in {i} iteration")
else:
    print("Sorry!!! you trials is exceeded. Try Again.")
# Out:
# Welcome to number guessing name!!!
# Guess the number between 1-100
# Enter your guess number: 41
# Your number is lesser
# Enter your guess number: 35
# Your number is lesser
# Enter your guess number: 30
# Your number is lesser
# Enter your guess number: 25
# Your number is lesser
# Enter your guess number: 10
# Your number is lesser
# Enter your guess number: 7
# Your number is lesser
# Enter your guess number: 4
# Your number is lesser
# Sorry!!! you trials is exceeded. Try Again.

# %%
import random

print("Welcome to guessing number game!!!")

print("Guess the number b/w 1 to 100.......")

secret_number = random.randint(1,100)

for i in range(1,8):
    
    user_input = int(input("Enter the number: "))

    if user_input<1 or user_input>100:
        print("Invalid Number")
    elif user_input > secret_number:
        print("Higher")
    elif user_input<secret_number:
        print("Lower")
    else:
        print("your guessed number is correct")

if secret_number == user_input:
    print("You won")
else:
    print("you lose, try again!")
# Out:
# Welcome to guessing number game!!!
# Guess the number b/w 1 to 100.......
# Enter the number:  85
# Higher
# Enter the number:  50
# Lower
# Enter the number:  60
# Higher
# Enter the number:  55
# Lower
# Enter the number:  57
# Lower
# Enter the number:  58
# Lower
# Enter the number:  59
# your guessed number is correct
# You won

# %%
import random

print("Welcome to guessing number game!!!")

print("Guess the number b/w 1 to 100.......")

secret_number = random.randint(1,100)

while True:
    
    user_input = int(input("Enter the number: "))

    if user_input<1 or user_input>100:
        print("Invalid Number")
    elif user_input > secret_number:
        print("Higher")
    elif user_input<secret_number:
        print("Lower")
    else:
        print("your guessed number is correct")

# %%
#overcome invalid input

# %%
#exception

# %%
import random

print("Welcome to guessing number game!!!")

print("Guess the number b/w 1 to 100.......")

secret_number = random.randint(1,100)

while True:
    try:
        user_input = int(input("Enter the number: "))
    
        if user_input<1 or user_input>100:
            print("Invalid Number")
        elif user_input > secret_number:
            print("Higher")
        elif user_input<secret_number:
            print("Lower")
        else:
            print("your guessed number is correct")
            break
    except ValueError:
        print("Invalid Characters")
# Out:
# Welcome to guessing number game!!!
# Guess the number b/w 1 to 100.......
# Enter the number:  4
# Lower
# Enter the number:  55
# Higher
# Enter the number:  35
# Lower
# Enter the number:  40
# Higher
# Enter the number:  37
# Lower
# Enter the number:  39
# your guessed number is correct

# %%
import random

print("Welcome to guessing number game!!!")

print("Guess the number b/w 1 to 100.......")

secret_number = random.randint(1,100)

while True:
    try:
        user_input = int(input("Enter the number: "))
    
        if user_input<1 or user_input>100:
            print("Invalid Number")
        elif user_input > secret_number:
            print("Higher")
        elif user_input<secret_number:
            print("Lower")
        else:
            print("your guessed number is correct")
            break
    except ValueError:
        print("Invalid Characters")
# Out:
# Welcome to guessing number game!!!
# Guess the number b/w 1 to 100.......
# Enter the number:  Chandru
# Invalid Characters
# Enter the number:  44
# Higher
# Enter the number:  5
# Lower
# Enter the number:  55
# Higher
# Enter the number:  55
# Higher
# Enter the number:  63
# Higher
# Enter the number:  65
# Higher
# Enter the number:  94
# Higher
# Enter the number:  15151
# Invalid Number
# Enter the number:  44
# Higher
# Enter the number:  55
# Higher
# Enter the number:  32
# Higher
# Enter the number:  1
# Lower
# Enter the number:  25
# Higher
# Enter the number:  20
# Higher
# Enter the number:  15
# Lower
# Enter the number:  19
# Higher
# Enter the number:  17
# Lower
# Enter the number:  18
# your guessed number is correct

# %%
#user def

# %%
def guessing_number_game():
    import random
    print("Welcome to guessing number game!!!")
    
    print("Guess the number b/w 1 to 100.......")
    
    secret_number = random.randint(1,100)
    
    while True:
        try:
            user_input = int(input("Enter the number: "))
        
            if user_input<1 or user_input>100:
                print("Invalid Number")
            elif user_input > secret_number:
                print("Higher")
            elif user_input<secret_number:
                print("Lower")
            else:
                print("your guessed number is correct")
                break
        except ValueError:
            print("Invalid Characters")

    if secret_number == user_input:
        print("You won")
    else:
        print("you lose, try again!")

# %%
guessing_number_game()
# Out:
# Welcome to guessing number game!!!
# Guess the number b/w 1 to 100.......
# Enter the number:  10
# Lower
# Enter the number:  50
# Lower
# Enter the number:  90
# Higher
# Enter the number:  85
# Higher
# Enter the number:  75
# Lower
# Enter the number:  80
# Lower
# Enter the number:  83
# Lower
# Enter the number:  84
# your guessed number is correct
# You won
