# %%
lst = []
type(lst)
# Out:
# list

# %%
tup = ()
type(tup)
# Out:
# tuple

# %%
names  = ['Devi','chandru','bharath','boomi']

# %%
names[1]
# Out:
# 'chandru'

# %%
print(names)
# Out:
# ['Devi', 'chandru', 'bharath', 'boomi']

# %%
fruits = ['apple', 'banana', 'cherry', 'date']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[2]
# Out:
# 'cherry'

# %%
fruits[3]
# Out:
# 'date'

# %%
print(fruits
      )
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %%
print(fruits[-1])
# Out:
# date

# %%
print(fruits[1:])
# Out:
# ['banana', 'cherry', 'date']

# %%
fruits[1] = 'strawberry'

# %%
fruits[1]
# Out:
# 'strawberry'

# %%
fruits = ['apple', 'banana', 'cherry', 'date','watermelon']

# %%
fruits.append("Orange")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'date', 'watermelon', 'Orange']
