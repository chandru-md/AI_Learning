# %%
print("md")
# Out:
# md

# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.6/24.4 MB 9.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.4/24.4 MB 8.7 MB/s eta 0:00:03
#    -------- ------------------------------- 5.0/24.4 MB 8.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 6.8/24.4 MB 8.5 MB/s eta 0:00:03
#    -------------- ------------------------- 8.7/24.4 MB 8.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.5/24.4 MB 8.5 MB/s eta 0:00:02
#    -------------------- ------------------- 12.3/24.4 MB 8.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.2/24.4 MB 8.4 MB/s eta 0:00:02
#    ------------------------- -------------- 15.7/24.4 MB 8.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 17.6/24.4 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 19.4/24.4 MB 8.4 MB/s eta 0:00:01
# ...

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format(r"C:\Users\CHANDRU DEIVANAYAGAN\Downloads\Compressed\GoogleNews-vectors-negative300.bin\GoogleNews-vectors-negative300.bin",binary=True)

# %%
result = model.most_similar(['stop'])

# %%
result
# Out:
# [('stopped', 0.683486819267273),
#  ('stopping', 0.6298909187316895),
#  ('stops', 0.617362916469574),
#  ('Stop', 0.6122490167617798),
#  ('halt', 0.6082639098167419),
#  ('prevent', 0.5375699400901794),
#  ('Stopping', 0.5060288906097412),
#  ('cease', 0.503141462802887),
#  ('dissuade', 0.4902012050151825),
#  ('deter', 0.4874151945114136)]

# %%
result_1 = model.most_similar(['hello'])

# %%
result_1
# Out:
# [('hi', 0.6548984050750732),
#  ('goodbye', 0.6399056315422058),
#  ('howdy', 0.6310956478118896),
#  ('goodnight', 0.5920577645301819),
#  ('greeting', 0.5855878591537476),
#  ('Hello', 0.5842196941375732),
#  ("g'day", 0.5754078030586243),
#  ('See_ya', 0.5688871741294861),
#  ('ya_doin', 0.5643120408058167),
#  ('greet', 0.5636603832244873)]

# %%
result_2 = model.most_similar(['style'])
result_2
# Out:
# [('styles', 0.6399438381195068),
#  ('flair', 0.6104061603546143),
#  ('syle', 0.6024925112724304),
#  ('styled', 0.5924667119979858),
#  ('stylings', 0.5438728928565979),
#  ('sytle', 0.5342130661010742),
#  ('size_##px', 0.5333694219589233),
#  ('sensibility', 0.5221040844917297),
#  ('elegance', 0.5098029971122742),
#  ('finesse', 0.5066274404525757)]

# %%
result_3 = model.most_similar(positive=['king','woman'],negative=['man'])
result_3
# Out:
# [('queen', 0.7118192911148071),
#  ('monarch', 0.6189674735069275),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321243286133),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.518113374710083),
#  ('sultan', 0.5098593831062317),
#  ('monarchy', 0.5087411999702454)]

# %%
## Glove Embedding

# %%
# !pip install flair
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 8.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/12.0 MB 9.0 MB/s eta 0:00:02
# ...

# %%
import numpy as np

from flair.data import Sentence
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 import numpy as np
# ----> 3 from flair.data import Sentence
#
# File c:\Anaconda3\Lib\site-packages\flair\data.py:20
#      18 import flair
#      19 from flair.file_utils import Tqdm
# ---> 20 from flair.tokenization import SegtokTokenizer, SpaceTokenizer, Tokenizer
#      22 T_co = typing.TypeVar("T_co", covariant=True)
#      24 log = logging.getLogger("flair")
#
# File c:\Anaconda3\Lib\site-packages\flair\__init__.py:43
#      40 # global variable: arrow symbol
#      41 _arrow = " → "
# ---> 43 from . import (  # noqa: E402 import after setting device
#      44     data,
#      45     models,
#      46     nn,
#      47     trainers,
#      48     visual,
#      49 )
#      51 logging.config.dictConfig(
#      52     {
#      53         "version": 1,
#    (...)
#      65     }
#      66 )
# ...

# %%
# !pip install torch

# %%
import numpy as np

from flair.data import Sentence

# %%
sentence = Sentence("Flair works correctly now")
print(sentence)
# Out:
# Sentence[4]: "Flair works correctly now"

# %%
# !pip install pyopenssl

# %%
glove_embedding = WordEmbeddings('glove')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 glove_embedding = WordEmbeddings('glove')
#
# NameError: name 'WordEmbeddings' is not defined

# %%
from flair.embeddings import WordEmbeddings

# %%
glove_embedding = WordEmbeddings('glove')
# Out:
# 2026-01-06 18:46:37,832 https://flair.informatik.hu-berlin.de/resources/embeddings/token/glove.gensim.vectors.npy not found in cache, downloading to C:\Users\CHANDR~1\AppData\Local\Temp\tmpcl80awqv
# 100%|██████████| 153M/153M [00:22<00:00, 7.13MB/s]
# 2026-01-06 18:47:01,156 copying C:\Users\CHANDR~1\AppData\Local\Temp\tmpcl80awqv to cache at C:\Users\CHANDRU DEIVANAYAGAN\.flair\embeddings\glove.gensim.vectors.npy
# 2026-01-06 18:47:01,276 removing temp file C:\Users\CHANDR~1\AppData\Local\Temp\tmpcl80awqv
# 2026-01-06 18:47:01,912 https://flair.informatik.hu-berlin.de/resources/embeddings/token/glove.gensim not found in cache, downloading to C:\Users\CHANDR~1\AppData\Local\Temp\tmpbwghusa9
# 100%|██████████| 20.5M/20.5M [00:05<00:00, 4.21MB/s]
# 2026-01-06 18:47:07,838 copying C:\Users\CHANDR~1\AppData\Local\Temp\tmpbwghusa9 to cache at C:\Users\CHANDRU DEIVANAYAGAN\.flair\embeddings\glove.gensim
# ...

# %%
sentence_1 = Sentence("The founder of Energetic AI is Chandru")

# %%
glove_embedding.embed(sentence_1)
# Out:
# [Sentence[7]: "The founder of Energetic AI is Chandru"]

# %%
for token in sentence_1:
    print(token)
    print(token.embedding)
    print("\n")
# Out:
# Token[0]: "The"
# tensor([-0.0382, -0.2449,  0.7281, -0.3996,  0.0832,  0.0440, -0.3914,  0.3344,
#         -0.5755,  0.0875,  0.2879, -0.0673,  0.3091, -0.2638, -0.1323, -0.2076,
#          0.3340, -0.3385, -0.3174, -0.4834,  0.1464, -0.3730,  0.3458,  0.0520,
#          0.4495, -0.4697,  0.0263, -0.5415, -0.1552, -0.1411, -0.0397,  0.2828,
#          0.1439,  0.2346, -0.3102,  0.0862,  0.2040,  0.5262,  0.1716, -0.0824,
#         -0.7179, -0.4153,  0.2033, -0.1276,  0.4137,  0.5519,  0.5791, -0.3348,
#         -0.3656, -0.5486, -0.0629,  0.2658,  0.3020,  0.9977, -0.8048, -3.0243,
#          0.0125, -0.3694,  2.2167,  0.7220, -0.2498,  0.9214,  0.0345,  0.4674,
#          1.1079, -0.1936, -0.0746,  0.2335, -0.0521, -0.2204,  0.0572, -0.1581,
#         -0.3080, -0.4162,  0.3797,  0.1501, -0.5321, -0.2055, -1.2526,  0.0716,
#          0.7056,  0.4974, -0.4206,  0.2615, -1.5380, -0.3022, -0.0734, -0.2831,
# ...

# %%
sentence[1]
# Out:
# Token[1]: "works"

# %%
sentence[0]
# Out:
# Token[0]: "Flair"
