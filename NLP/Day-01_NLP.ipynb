# %%
text = '''Quantum Computing: Redefining the Limits of Computation

Quantum computing represents a fundamental shift in how problems are processed and solved by machines. Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use quantum bits, or qubits. Qubits leverage the principles of quantum mechanics—such as superposition and entanglement—to perform computations in ways that are impossible for traditional systems. This unique capability positions quantum computing as a breakthrough technology with the potential to solve problems far beyond the reach of today’s fastest supercomputers.

At the heart of quantum computing is superposition, which allows a qubit to exist in multiple states simultaneously. This means a quantum computer can explore many possible solutions at the same time rather than checking them one by one. Entanglement further enhances this power by linking qubits so that the state of one instantly influences another, even across distance. Together, these properties enable massive parallelism and exponential speedups for specific classes of problems.

The potential applications of quantum computing are transformative. In cryptography, quantum computers could break widely used encryption methods, prompting the development of quantum-resistant security systems. In chemistry and materials science, they can simulate molecular interactions with high precision, accelerating drug discovery and the creation of advanced materials. Optimization problems in logistics, finance, and supply chains—often too complex for classical computers—can be approached more efficiently with quantum algorithms.

Despite its promise, quantum computing is still in an early stage. Qubits are extremely sensitive to environmental noise, leading to errors and instability. Building reliable, large-scale quantum systems requires advanced error correction, precise control mechanisms, and significant engineering breakthroughs. As a result, most current quantum computers are experimental and limited in practical use.

Looking ahead, quantum computing is expected to complement rather than replace classical computing. Hybrid systems, where quantum processors handle specific complex tasks while classical computers manage general operations, are likely to define the near future. Continued research, investment, and collaboration between academia, industry, and governments will be essential to unlock its full potential.

In conclusion, quantum computing marks a new era in computational science. While challenges remain, its ability to tackle previously unsolvable problems could reshape industries, strengthen scientific discovery, and redefine what is computationally possible.'''

# %%
text
# Out:
# 'Quantum Computing: Redefining the Limits of Computation\n\nQuantum computing represents a fundamental shift in how problems are processed and solved by machines. Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use quantum bits, or qubits. Qubits leverage the principles of quantum mechanics—such as superposition and entanglement—to perform computations in ways that are impossible for traditional systems. This unique capability positions quantum computing as a breakthrough technology with the potential to solve problems far beyond the reach of today’s fastest supercomputers.\n\nAt the heart of quantum computing is superposition, which allows a qubit to exist in multiple states simultaneously. This means a quantum computer can explore many possible solutions at the same time rather than checking them one by one. Entanglement further enhances this power by linking qubits so that the state of one instantly influences another, even across distance. Together, these properties enable massive parallelism and exponential speedups for specific classes of problems.\n\nThe potential applications of quantum computing are transformative. In cryptography, quantum computers could break widely used encryption methods, prompting the development of quantum-resistant security systems. In chemistry and materials science, they can simulate molecular interactions with high precision, accelerating drug discovery and the creation of advanced materials. Optimization problems in logistics, finance, and supply chains—often too complex for classical computers—can be approached more efficiently with quantum algorithms.\n\nDespite its promise, quantum computing is still in an early stage. Qubits are extremely sensitive to environmental noise, leading to errors and instability. Building reliable, large-scale quantum systems requires advanced error correction, precise control mechanisms, and significant engineering breakthroughs. As a result, most current quantum computers are experimental and limited in practical use.\n\nLooking ahead, quantum computing is expected to complement rather than replace classical computing. Hybrid systems, where quantum processors handle specific complex tasks while classical computers manage general operations, are likely to define the near future. Continued research, investment, and collaboration between academia, industry, and governments will be essential to unlock its full potential.\n\nIn conclusion, quantum computing marks a new era in computational science. While challenges remain, its ability to tackle previously unsolvable problems could reshape industries, strengthen scientific discovery, and redefine what is computationally possible.'

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt_tab')
Sentences = sent_tokenize(text)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
text
# Out:
# 'Quantum Computing: Redefining the Limits of Computation\n\nQuantum computing represents a fundamental shift in how problems are processed and solved by machines. Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use quantum bits, or qubits. Qubits leverage the principles of quantum mechanics—such as superposition and entanglement—to perform computations in ways that are impossible for traditional systems. This unique capability positions quantum computing as a breakthrough technology with the potential to solve problems far beyond the reach of today’s fastest supercomputers.\n\nAt the heart of quantum computing is superposition, which allows a qubit to exist in multiple states simultaneously. This means a quantum computer can explore many possible solutions at the same time rather than checking them one by one. Entanglement further enhances this power by linking qubits so that the state of one instantly influences another, even across distance. Together, these properties enable massive parallelism and exponential speedups for specific classes of problems.\n\nThe potential applications of quantum computing are transformative. In cryptography, quantum computers could break widely used encryption methods, prompting the development of quantum-resistant security systems. In chemistry and materials science, they can simulate molecular interactions with high precision, accelerating drug discovery and the creation of advanced materials. Optimization problems in logistics, finance, and supply chains—often too complex for classical computers—can be approached more efficiently with quantum algorithms.\n\nDespite its promise, quantum computing is still in an early stage. Qubits are extremely sensitive to environmental noise, leading to errors and instability. Building reliable, large-scale quantum systems requires advanced error correction, precise control mechanisms, and significant engineering breakthroughs. As a result, most current quantum computers are experimental and limited in practical use.\n\nLooking ahead, quantum computing is expected to complement rather than replace classical computing. Hybrid systems, where quantum processors handle specific complex tasks while classical computers manage general operations, are likely to define the near future. Continued research, investment, and collaboration between academia, industry, and governments will be essential to unlock its full potential.\n\nIn conclusion, quantum computing marks a new era in computational science. While challenges remain, its ability to tackle previously unsolvable problems could reshape industries, strengthen scientific discovery, and redefine what is computationally possible.'

# %%
Sentences
# Out:
# ['Quantum Computing: Redefining the Limits of Computation\n\nQuantum computing represents a fundamental shift in how problems are processed and solved by machines.',
#  'Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use quantum bits, or qubits.',
#  'Qubits leverage the principles of quantum mechanics—such as superposition and entanglement—to perform computations in ways that are impossible for traditional systems.',
#  'This unique capability positions quantum computing as a breakthrough technology with the potential to solve problems far beyond the reach of today’s fastest supercomputers.',
#  'At the heart of quantum computing is superposition, which allows a qubit to exist in multiple states simultaneously.',
#  'This means a quantum computer can explore many possible solutions at the same time rather than checking them one by one.',
#  'Entanglement further enhances this power by linking qubits so that the state of one instantly influences another, even across distance.',
#  'Together, these properties enable massive parallelism and exponential speedups for specific classes of problems.',
#  'The potential applications of quantum computing are transformative.',
#  'In cryptography, quantum computers could break widely used encryption methods, prompting the development of quantum-resistant security systems.',
#  'In chemistry and materials science, they can simulate molecular interactions with high precision, accelerating drug discovery and the creation of advanced materials.',
#  'Optimization problems in logistics, finance, and supply chains—often too complex for classical computers—can be approached more efficiently with quantum algorithms.',
#  'Despite its promise, quantum computing is still in an early stage.',
#  'Qubits are extremely sensitive to environmental noise, leading to errors and instability.',
#  'Building reliable, large-scale quantum systems requires advanced error correction, precise control mechanisms, and significant engineering breakthroughs.',
#  'As a result, most current quantum computers are experimental and limited in practical use.',
#  'Looking ahead, quantum computing is expected to complement rather than replace classical computing.',
#  'Hybrid systems, where quantum processors handle specific complex tasks while classical computers manage general operations, are likely to define the near future.',
#  'Continued research, investment, and collaboration between academia, industry, and governments will be essential to unlock its full potential.',
#  'In conclusion, quantum computing marks a new era in computational science.',
#  'While challenges remain, its ability to tackle previously unsolvable problems could reshape industries, strengthen scientific discovery, and redefine what is computationally possible.']

# %% [markdown]
# Word Tokenization

# %%
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(text)

# %%
words
# Out:
# ['Quantum',
#  'Computing',
#  ':',
#  'Redefining',
#  'the',
#  'Limits',
#  'of',
#  'Computation',
#  'Quantum',
#  'computing',
#  'represents',
#  'a',
#  'fundamental',
#  'shift',
#  'in',
#  'how',
#  'problems',
#  'are',
#  'processed',
#  'and',
#  'solved',
#  'by',
#  'machines',
#  '.',
#  'Unlike',
#  'classical',
#  'computers',
#  ',',
#  'which',
#  'use',
#  'bits',
#  'that',
#  'exist',
#  'as',
#  'either',
#  '0',
#  'or',
#  '1',
#  ',',
#  'quantum',
#  'computers',
#  'use',
#  'quantum',
#  'bits',
#  ',',
#  'or',
#  'qubits',
#  '.',
#  'Qubits',
#  'leverage',
#  'the',
#  'principles',
#  'of',
#  'quantum',
#  'mechanics—such',
#  'as',
#  'superposition',
#  'and',
#  'entanglement—to',
#  'perform',
#  'computations',
#  'in',
#  'ways',
#  'that',
#  'are',
#  'impossible',
#  'for',
#  'traditional',
#  'systems',
#  '.',
#  'This',
#  'unique',
#  'capability',
#  'positions',
#  'quantum',
#  'computing',
#  'as',
#  'a',
#  'breakthrough',
#  'technology',
#  'with',
#  'the',
#  'potential',
#  'to',
#  'solve',
#  'problems',
#  'far',
#  'beyond',
#  'the',
#  'reach',
#  'of',
#  'today',
#  '’',
#  's',
#  'fastest',
#  'supercomputers',
#  '.',
#  'At',
#  'the',
#  'heart',
#  'of',
#  'quantum',
#  'computing',
#  'is',
#  'superposition',
#  ',',
#  'which',
#  'allows',
#  'a',
#  'qubit',
#  'to',
#  'exist',
#  'in',
#  'multiple',
#  'states',
#  'simultaneously',
#  '.',
#  'This',
#  'means',
#  'a',
#  'quantum',
#  'computer',
#  'can',
#  'explore',
#  'many',
#  'possible',
#  'solutions',
#  'at',
#  'the',
#  'same',
#  'time',
#  'rather',
#  'than',
#  'checking',
#  'them',
#  'one',
#  'by',
#  'one',
#  '.',
#  'Entanglement',
#  'further',
#  'enhances',
#  'this',
#  'power',
#  'by',
#  'linking',
#  'qubits',
#  'so',
#  'that',
#  'the',
#  'state',
#  'of',
#  'one',
#  'instantly',
#  'influences',
#  'another',
#  ',',
#  'even',
#  'across',
#  'distance',
#  '.',
#  'Together',
#  ',',
#  'these',
#  'properties',
#  'enable',
#  'massive',
#  'parallelism',
#  'and',
#  'exponential',
#  'speedups',
#  'for',
#  'specific',
#  'classes',
#  'of',
#  'problems',
#  '.',
#  'The',
#  'potential',
#  'applications',
#  'of',
#  'quantum',
#  'computing',
#  'are',
#  'transformative',
#  '.',
#  'In',
#  'cryptography',
#  ',',
#  'quantum',
#  'computers',
#  'could',
#  'break',
#  'widely',
#  'used',
#  'encryption',
#  'methods',
#  ',',
#  'prompting',
#  'the',
#  'development',
#  'of',
#  'quantum-resistant',
#  'security',
#  'systems',
#  '.',
#  'In',
#  'chemistry',
#  'and',
#  'materials',
#  'science',
#  ',',
#  'they',
#  'can',
#  'simulate',
#  'molecular',
#  'interactions',
#  'with',
#  'high',
#  'precision',
#  ',',
#  'accelerating',
#  'drug',
#  'discovery',
#  'and',
#  'the',
#  'creation',
#  'of',
#  'advanced',
#  'materials',
#  '.',
#  'Optimization',
#  'problems',
#  'in',
#  'logistics',
#  ',',
#  'finance',
#  ',',
#  'and',
#  'supply',
#  'chains—often',
#  'too',
#  'complex',
#  'for',
#  'classical',
#  'computers—can',
#  'be',
#  'approached',
#  'more',
#  'efficiently',
#  'with',
#  'quantum',
#  'algorithms',
#  '.',
#  'Despite',
#  'its',
#  'promise',
#  ',',
#  'quantum',
#  'computing',
#  'is',
#  'still',
#  'in',
#  'an',
#  'early',
#  'stage',
#  '.',
#  'Qubits',
#  'are',
#  'extremely',
#  'sensitive',
#  'to',
#  'environmental',
#  'noise',
#  ',',
#  'leading',
#  'to',
#  'errors',
#  'and',
#  'instability',
#  '.',
#  'Building',
#  'reliable',
#  ',',
#  'large-scale',
#  'quantum',
#  'systems',
#  'requires',
#  'advanced',
#  'error',
#  'correction',
#  ',',
#  'precise',
#  'control',
#  'mechanisms',
#  ',',
#  'and',
#  'significant',
#  'engineering',
#  'breakthroughs',
#  '.',
#  'As',
#  'a',
#  'result',
#  ',',
#  'most',
#  'current',
#  'quantum',
#  'computers',
#  'are',
#  'experimental',
#  'and',
#  'limited',
#  'in',
#  'practical',
#  'use',
#  '.',
#  'Looking',
#  'ahead',
#  ',',
#  'quantum',
#  'computing',
#  'is',
#  'expected',
#  'to',
#  'complement',
#  'rather',
#  'than',
#  'replace',
#  'classical',
#  'computing',
#  '.',
#  'Hybrid',
#  'systems',
#  ',',
#  'where',
#  'quantum',
#  'processors',
#  'handle',
#  'specific',
#  'complex',
#  'tasks',
#  'while',
#  'classical',
#  'computers',
#  'manage',
#  'general',
#  'operations',
#  ',',
#  'are',
#  'likely',
#  'to',
#  'define',
#  'the',
#  'near',
#  'future',
#  '.',
#  'Continued',
#  'research',
#  ',',
#  'investment',
#  ',',
#  'and',
#  'collaboration',
#  'between',
#  'academia',
#  ',',
#  'industry',
#  ',',
#  'and',
#  'governments',
#  'will',
#  'be',
#  'essential',
#  'to',
#  'unlock',
#  'its',
#  'full',
#  'potential',
#  '.',
#  'In',
#  'conclusion',
#  ',',
#  'quantum',
#  'computing',
#  'marks',
#  'a',
#  'new',
#  'era',
#  'in',
#  'computational',
#  'science',
#  '.',
#  'While',
#  'challenges',
#  'remain',
#  ',',
#  'its',
#  'ability',
#  'to',
#  'tackle',
#  'previously',
#  'unsolvable',
#  'problems',
#  'could',
#  'reshape',
#  'industries',
#  ',',
#  'strengthen',
#  'scientific',
#  'discovery',
#  ',',
#  'and',
#  'redefine',
#  'what',
#  'is',
#  'computationally',
#  'possible',
#  '.']

# %% [markdown]
# Lower case

# %%
lower_sent = [sentence .lower() for sentence in Sentences]

# %%
lower_sent
# Out:
# ['quantum computing: redefining the limits of computation\n\nquantum computing represents a fundamental shift in how problems are processed and solved by machines.',
#  'unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use quantum bits, or qubits.',
#  'qubits leverage the principles of quantum mechanics—such as superposition and entanglement—to perform computations in ways that are impossible for traditional systems.',
#  'this unique capability positions quantum computing as a breakthrough technology with the potential to solve problems far beyond the reach of today’s fastest supercomputers.',
#  'at the heart of quantum computing is superposition, which allows a qubit to exist in multiple states simultaneously.',
#  'this means a quantum computer can explore many possible solutions at the same time rather than checking them one by one.',
#  'entanglement further enhances this power by linking qubits so that the state of one instantly influences another, even across distance.',
#  'together, these properties enable massive parallelism and exponential speedups for specific classes of problems.',
#  'the potential applications of quantum computing are transformative.',
#  'in cryptography, quantum computers could break widely used encryption methods, prompting the development of quantum-resistant security systems.',
#  'in chemistry and materials science, they can simulate molecular interactions with high precision, accelerating drug discovery and the creation of advanced materials.',
#  'optimization problems in logistics, finance, and supply chains—often too complex for classical computers—can be approached more efficiently with quantum algorithms.',
#  'despite its promise, quantum computing is still in an early stage.',
#  'qubits are extremely sensitive to environmental noise, leading to errors and instability.',
#  'building reliable, large-scale quantum systems requires advanced error correction, precise control mechanisms, and significant engineering breakthroughs.',
#  'as a result, most current quantum computers are experimental and limited in practical use.',
#  'looking ahead, quantum computing is expected to complement rather than replace classical computing.',
#  'hybrid systems, where quantum processors handle specific complex tasks while classical computers manage general operations, are likely to define the near future.',
#  'continued research, investment, and collaboration between academia, industry, and governments will be essential to unlock its full potential.',
#  'in conclusion, quantum computing marks a new era in computational science.',
#  'while challenges remain, its ability to tackle previously unsolvable problems could reshape industries, strengthen scientific discovery, and redefine what is computationally possible.']

# %%
lower_word = [word.lower() for word in words]

# %%
lower_word
# Out:
# ['quantum',
#  'computing',
#  ':',
#  'redefining',
#  'the',
#  'limits',
#  'of',
#  'computation',
#  'quantum',
#  'computing',
#  'represents',
#  'a',
#  'fundamental',
#  'shift',
#  'in',
#  'how',
#  'problems',
#  'are',
#  'processed',
#  'and',
#  'solved',
#  'by',
#  'machines',
#  '.',
#  'unlike',
#  'classical',
#  'computers',
#  ',',
#  'which',
#  'use',
#  'bits',
#  'that',
#  'exist',
#  'as',
#  'either',
#  '0',
#  'or',
#  '1',
#  ',',
#  'quantum',
#  'computers',
#  'use',
#  'quantum',
#  'bits',
#  ',',
#  'or',
#  'qubits',
#  '.',
#  'qubits',
#  'leverage',
#  'the',
#  'principles',
#  'of',
#  'quantum',
#  'mechanics—such',
#  'as',
#  'superposition',
#  'and',
#  'entanglement—to',
#  'perform',
#  'computations',
#  'in',
#  'ways',
#  'that',
#  'are',
#  'impossible',
#  'for',
#  'traditional',
#  'systems',
#  '.',
#  'this',
#  'unique',
#  'capability',
#  'positions',
#  'quantum',
#  'computing',
#  'as',
#  'a',
#  'breakthrough',
#  'technology',
#  'with',
#  'the',
#  'potential',
#  'to',
#  'solve',
#  'problems',
#  'far',
#  'beyond',
#  'the',
#  'reach',
#  'of',
#  'today',
#  '’',
#  's',
#  'fastest',
#  'supercomputers',
#  '.',
#  'at',
#  'the',
#  'heart',
#  'of',
#  'quantum',
#  'computing',
#  'is',
#  'superposition',
#  ',',
#  'which',
#  'allows',
#  'a',
#  'qubit',
#  'to',
#  'exist',
#  'in',
#  'multiple',
#  'states',
#  'simultaneously',
#  '.',
#  'this',
#  'means',
#  'a',
#  'quantum',
#  'computer',
#  'can',
#  'explore',
#  'many',
#  'possible',
#  'solutions',
#  'at',
#  'the',
#  'same',
#  'time',
#  'rather',
#  'than',
#  'checking',
#  'them',
#  'one',
#  'by',
#  'one',
#  '.',
#  'entanglement',
#  'further',
#  'enhances',
#  'this',
#  'power',
#  'by',
#  'linking',
#  'qubits',
#  'so',
#  'that',
#  'the',
#  'state',
#  'of',
#  'one',
#  'instantly',
#  'influences',
#  'another',
#  ',',
#  'even',
#  'across',
#  'distance',
#  '.',
#  'together',
#  ',',
#  'these',
#  'properties',
#  'enable',
#  'massive',
#  'parallelism',
#  'and',
#  'exponential',
#  'speedups',
#  'for',
#  'specific',
#  'classes',
#  'of',
#  'problems',
#  '.',
#  'the',
#  'potential',
#  'applications',
#  'of',
#  'quantum',
#  'computing',
#  'are',
#  'transformative',
#  '.',
#  'in',
#  'cryptography',
#  ',',
#  'quantum',
#  'computers',
#  'could',
#  'break',
#  'widely',
#  'used',
#  'encryption',
#  'methods',
#  ',',
#  'prompting',
#  'the',
#  'development',
#  'of',
#  'quantum-resistant',
#  'security',
#  'systems',
#  '.',
#  'in',
#  'chemistry',
#  'and',
#  'materials',
#  'science',
#  ',',
#  'they',
#  'can',
#  'simulate',
#  'molecular',
#  'interactions',
#  'with',
#  'high',
#  'precision',
#  ',',
#  'accelerating',
#  'drug',
#  'discovery',
#  'and',
#  'the',
#  'creation',
#  'of',
#  'advanced',
#  'materials',
#  '.',
#  'optimization',
#  'problems',
#  'in',
#  'logistics',
#  ',',
#  'finance',
#  ',',
#  'and',
#  'supply',
#  'chains—often',
#  'too',
#  'complex',
#  'for',
#  'classical',
#  'computers—can',
#  'be',
#  'approached',
#  'more',
#  'efficiently',
#  'with',
#  'quantum',
#  'algorithms',
#  '.',
#  'despite',
#  'its',
#  'promise',
#  ',',
#  'quantum',
#  'computing',
#  'is',
#  'still',
#  'in',
#  'an',
#  'early',
#  'stage',
#  '.',
#  'qubits',
#  'are',
#  'extremely',
#  'sensitive',
#  'to',
#  'environmental',
#  'noise',
#  ',',
#  'leading',
#  'to',
#  'errors',
#  'and',
#  'instability',
#  '.',
#  'building',
#  'reliable',
#  ',',
#  'large-scale',
#  'quantum',
#  'systems',
#  'requires',
#  'advanced',
#  'error',
#  'correction',
#  ',',
#  'precise',
#  'control',
#  'mechanisms',
#  ',',
#  'and',
#  'significant',
#  'engineering',
#  'breakthroughs',
#  '.',
#  'as',
#  'a',
#  'result',
#  ',',
#  'most',
#  'current',
#  'quantum',
#  'computers',
#  'are',
#  'experimental',
#  'and',
#  'limited',
#  'in',
#  'practical',
#  'use',
#  '.',
#  'looking',
#  'ahead',
#  ',',
#  'quantum',
#  'computing',
#  'is',
#  'expected',
#  'to',
#  'complement',
#  'rather',
#  'than',
#  'replace',
#  'classical',
#  'computing',
#  '.',
#  'hybrid',
#  'systems',
#  ',',
#  'where',
#  'quantum',
#  'processors',
#  'handle',
#  'specific',
#  'complex',
#  'tasks',
#  'while',
#  'classical',
#  'computers',
#  'manage',
#  'general',
#  'operations',
#  ',',
#  'are',
#  'likely',
#  'to',
#  'define',
#  'the',
#  'near',
#  'future',
#  '.',
#  'continued',
#  'research',
#  ',',
#  'investment',
#  ',',
#  'and',
#  'collaboration',
#  'between',
#  'academia',
#  ',',
#  'industry',
#  ',',
#  'and',
#  'governments',
#  'will',
#  'be',
#  'essential',
#  'to',
#  'unlock',
#  'its',
#  'full',
#  'potential',
#  '.',
#  'in',
#  'conclusion',
#  ',',
#  'quantum',
#  'computing',
#  'marks',
#  'a',
#  'new',
#  'era',
#  'in',
#  'computational',
#  'science',
#  '.',
#  'while',
#  'challenges',
#  'remain',
#  ',',
#  'its',
#  'ability',
#  'to',
#  'tackle',
#  'previously',
#  'unsolvable',
#  'problems',
#  'could',
#  'reshape',
#  'industries',
#  ',',
#  'strengthen',
#  'scientific',
#  'discovery',
#  ',',
#  'and',
#  'redefine',
#  'what',
#  'is',
#  'computationally',
#  'possible',
#  '.']

# %%
len(words)
# Out:
# 419

# %% [markdown]
# remove stop-words

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words("english"))

# %%
clean_data = [word for word in words if word.lower() not in stop_words and word.isalpha()]

# %%
clean_data
# Out:
# ['Quantum',
#  'Computing',
#  'Redefining',
#  'Limits',
#  'Computation',
#  'Quantum',
#  'computing',
#  'represents',
#  'fundamental',
#  'shift',
#  'problems',
#  'processed',
#  'solved',
#  'machines',
#  'Unlike',
#  'classical',
#  'computers',
#  'use',
#  'bits',
#  'exist',
#  'either',
#  'quantum',
#  'computers',
#  'use',
#  'quantum',
#  'bits',
#  'qubits',
#  'Qubits',
#  'leverage',
#  'principles',
#  'quantum',
#  'superposition',
#  'perform',
#  'computations',
#  'ways',
#  'impossible',
#  'traditional',
#  'systems',
#  'unique',
#  'capability',
#  'positions',
#  'quantum',
#  'computing',
#  'breakthrough',
#  'technology',
#  'potential',
#  'solve',
#  'problems',
#  'far',
#  'beyond',
#  'reach',
#  'today',
#  'fastest',
#  'supercomputers',
#  'heart',
#  'quantum',
#  'computing',
#  'superposition',
#  'allows',
#  'qubit',
#  'exist',
#  'multiple',
#  'states',
#  'simultaneously',
#  'means',
#  'quantum',
#  'computer',
#  'explore',
#  'many',
#  'possible',
#  'solutions',
#  'time',
#  'rather',
#  'checking',
#  'one',
#  'one',
#  'Entanglement',
#  'enhances',
#  'power',
#  'linking',
#  'qubits',
#  'state',
#  'one',
#  'instantly',
#  'influences',
#  'another',
#  'even',
#  'across',
#  'distance',
#  'Together',
#  'properties',
#  'enable',
#  'massive',
#  'parallelism',
#  'exponential',
#  'speedups',
#  'specific',
#  'classes',
#  'problems',
#  'potential',
#  'applications',
#  'quantum',
#  'computing',
#  'transformative',
#  'cryptography',
#  'quantum',
#  'computers',
#  'could',
#  'break',
#  'widely',
#  'used',
#  'encryption',
#  'methods',
#  'prompting',
#  'development',
#  'security',
#  'systems',
#  'chemistry',
#  'materials',
#  'science',
#  'simulate',
#  'molecular',
#  'interactions',
#  'high',
#  'precision',
#  'accelerating',
#  'drug',
#  'discovery',
#  'creation',
#  'advanced',
#  'materials',
#  'Optimization',
#  'problems',
#  'logistics',
#  'finance',
#  'supply',
#  'complex',
#  'classical',
#  'approached',
#  'efficiently',
#  'quantum',
#  'algorithms',
#  'Despite',
#  'promise',
#  'quantum',
#  'computing',
#  'still',
#  'early',
#  'stage',
#  'Qubits',
#  'extremely',
#  'sensitive',
#  'environmental',
#  'noise',
#  'leading',
#  'errors',
#  'instability',
#  'Building',
#  'reliable',
#  'quantum',
#  'systems',
#  'requires',
#  'advanced',
#  'error',
#  'correction',
#  'precise',
#  'control',
#  'mechanisms',
#  'significant',
#  'engineering',
#  'breakthroughs',
#  'result',
#  'current',
#  'quantum',
#  'computers',
#  'experimental',
#  'limited',
#  'practical',
#  'use',
#  'Looking',
#  'ahead',
#  'quantum',
#  'computing',
#  'expected',
#  'complement',
#  'rather',
#  'replace',
#  'classical',
#  'computing',
#  'Hybrid',
#  'systems',
#  'quantum',
#  'processors',
#  'handle',
#  'specific',
#  'complex',
#  'tasks',
#  'classical',
#  'computers',
#  'manage',
#  'general',
#  'operations',
#  'likely',
#  'define',
#  'near',
#  'future',
#  'Continued',
#  'research',
#  'investment',
#  'collaboration',
#  'academia',
#  'industry',
#  'governments',
#  'essential',
#  'unlock',
#  'full',
#  'potential',
#  'conclusion',
#  'quantum',
#  'computing',
#  'marks',
#  'new',
#  'era',
#  'computational',
#  'science',
#  'challenges',
#  'remain',
#  'ability',
#  'tackle',
#  'previously',
#  'unsolvable',
#  'problems',
#  'could',
#  'reshape',
#  'industries',
#  'strengthen',
#  'scientific',
#  'discovery',
#  'redefine',
#  'computationally',
#  'possible']

# %%
len(clean_data)
# Out:
# 241

# %%
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
# STEMMING

# %%
stemmer = PorterStemmer()

# %%
stemmed_data = [stemmer.stem(word) for word in clean_data]

# %%
stemmed_data
# Out:
# ['quantum',
#  'comput',
#  'redefin',
#  'limit',
#  'comput',
#  'quantum',
#  'comput',
#  'repres',
#  'fundament',
#  'shift',
#  'problem',
#  'process',
#  'solv',
#  'machin',
#  'unlik',
#  'classic',
#  'comput',
#  'use',
#  'bit',
#  'exist',
#  'either',
#  'quantum',
#  'comput',
#  'use',
#  'quantum',
#  'bit',
#  'qubit',
#  'qubit',
#  'leverag',
#  'principl',
#  'quantum',
#  'superposit',
#  'perform',
#  'comput',
#  'way',
#  'imposs',
#  'tradit',
#  'system',
#  'uniqu',
#  'capabl',
#  'posit',
#  'quantum',
#  'comput',
#  'breakthrough',
#  'technolog',
#  'potenti',
#  'solv',
#  'problem',
#  'far',
#  'beyond',
#  'reach',
#  'today',
#  'fastest',
#  'supercomput',
#  'heart',
#  'quantum',
#  'comput',
#  'superposit',
#  'allow',
#  'qubit',
#  'exist',
#  'multipl',
#  'state',
#  'simultan',
#  'mean',
#  'quantum',
#  'comput',
#  'explor',
#  'mani',
#  'possibl',
#  'solut',
#  'time',
#  'rather',
#  'check',
#  'one',
#  'one',
#  'entangl',
#  'enhanc',
#  'power',
#  'link',
#  'qubit',
#  'state',
#  'one',
#  'instantli',
#  'influenc',
#  'anoth',
#  'even',
#  'across',
#  'distanc',
#  'togeth',
#  'properti',
#  'enabl',
#  'massiv',
#  'parallel',
#  'exponenti',
#  'speedup',
#  'specif',
#  'class',
#  'problem',
#  'potenti',
#  'applic',
#  'quantum',
#  'comput',
#  'transform',
#  'cryptographi',
#  'quantum',
#  'comput',
#  'could',
#  'break',
#  'wide',
#  'use',
#  'encrypt',
#  'method',
#  'prompt',
#  'develop',
#  'secur',
#  'system',
#  'chemistri',
#  'materi',
#  'scienc',
#  'simul',
#  'molecular',
#  'interact',
#  'high',
#  'precis',
#  'acceler',
#  'drug',
#  'discoveri',
#  'creation',
#  'advanc',
#  'materi',
#  'optim',
#  'problem',
#  'logist',
#  'financ',
#  'suppli',
#  'complex',
#  'classic',
#  'approach',
#  'effici',
#  'quantum',
#  'algorithm',
#  'despit',
#  'promis',
#  'quantum',
#  'comput',
#  'still',
#  'earli',
#  'stage',
#  'qubit',
#  'extrem',
#  'sensit',
#  'environment',
#  'nois',
#  'lead',
#  'error',
#  'instabl',
#  'build',
#  'reliabl',
#  'quantum',
#  'system',
#  'requir',
#  'advanc',
#  'error',
#  'correct',
#  'precis',
#  'control',
#  'mechan',
#  'signific',
#  'engin',
#  'breakthrough',
#  'result',
#  'current',
#  'quantum',
#  'comput',
#  'experiment',
#  'limit',
#  'practic',
#  'use',
#  'look',
#  'ahead',
#  'quantum',
#  'comput',
#  'expect',
#  'complement',
#  'rather',
#  'replac',
#  'classic',
#  'comput',
#  'hybrid',
#  'system',
#  'quantum',
#  'processor',
#  'handl',
#  'specif',
#  'complex',
#  'task',
#  'classic',
#  'comput',
#  'manag',
#  'gener',
#  'oper',
#  'like',
#  'defin',
#  'near',
#  'futur',
#  'continu',
#  'research',
#  'invest',
#  'collabor',
#  'academia',
#  'industri',
#  'govern',
#  'essenti',
#  'unlock',
#  'full',
#  'potenti',
#  'conclus',
#  'quantum',
#  'comput',
#  'mark',
#  'new',
#  'era',
#  'comput',
#  'scienc',
#  'challeng',
#  'remain',
#  'abil',
#  'tackl',
#  'previous',
#  'unsolv',
#  'problem',
#  'could',
#  'reshap',
#  'industri',
#  'strengthen',
#  'scientif',
#  'discoveri',
#  'redefin',
#  'comput',
#  'possibl']

# %%
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer_data = [lemmatizer.lemmatize(word) for word in clean_data]

# %%
lemmatizer_data
# Out:
# ['Quantum',
#  'Computing',
#  'Redefining',
#  'Limits',
#  'Computation',
#  'Quantum',
#  'computing',
#  'represents',
#  'fundamental',
#  'shift',
#  'problem',
#  'processed',
#  'solved',
#  'machine',
#  'Unlike',
#  'classical',
#  'computer',
#  'use',
#  'bit',
#  'exist',
#  'either',
#  'quantum',
#  'computer',
#  'use',
#  'quantum',
#  'bit',
#  'qubits',
#  'Qubits',
#  'leverage',
#  'principle',
#  'quantum',
#  'superposition',
#  'perform',
#  'computation',
#  'way',
#  'impossible',
#  'traditional',
#  'system',
#  'unique',
#  'capability',
#  'position',
#  'quantum',
#  'computing',
#  'breakthrough',
#  'technology',
#  'potential',
#  'solve',
#  'problem',
#  'far',
#  'beyond',
#  'reach',
#  'today',
#  'fastest',
#  'supercomputer',
#  'heart',
#  'quantum',
#  'computing',
#  'superposition',
#  'allows',
#  'qubit',
#  'exist',
#  'multiple',
#  'state',
#  'simultaneously',
#  'mean',
#  'quantum',
#  'computer',
#  'explore',
#  'many',
#  'possible',
#  'solution',
#  'time',
#  'rather',
#  'checking',
#  'one',
#  'one',
#  'Entanglement',
#  'enhances',
#  'power',
#  'linking',
#  'qubits',
#  'state',
#  'one',
#  'instantly',
#  'influence',
#  'another',
#  'even',
#  'across',
#  'distance',
#  'Together',
#  'property',
#  'enable',
#  'massive',
#  'parallelism',
#  'exponential',
#  'speedup',
#  'specific',
#  'class',
#  'problem',
#  'potential',
#  'application',
#  'quantum',
#  'computing',
#  'transformative',
#  'cryptography',
#  'quantum',
#  'computer',
#  'could',
#  'break',
#  'widely',
#  'used',
#  'encryption',
#  'method',
#  'prompting',
#  'development',
#  'security',
#  'system',
#  'chemistry',
#  'material',
#  'science',
#  'simulate',
#  'molecular',
#  'interaction',
#  'high',
#  'precision',
#  'accelerating',
#  'drug',
#  'discovery',
#  'creation',
#  'advanced',
#  'material',
#  'Optimization',
#  'problem',
#  'logistics',
#  'finance',
#  'supply',
#  'complex',
#  'classical',
#  'approached',
#  'efficiently',
#  'quantum',
#  'algorithm',
#  'Despite',
#  'promise',
#  'quantum',
#  'computing',
#  'still',
#  'early',
#  'stage',
#  'Qubits',
#  'extremely',
#  'sensitive',
#  'environmental',
#  'noise',
#  'leading',
#  'error',
#  'instability',
#  'Building',
#  'reliable',
#  'quantum',
#  'system',
#  'requires',
#  'advanced',
#  'error',
#  'correction',
#  'precise',
#  'control',
#  'mechanism',
#  'significant',
#  'engineering',
#  'breakthrough',
#  'result',
#  'current',
#  'quantum',
#  'computer',
#  'experimental',
#  'limited',
#  'practical',
#  'use',
#  'Looking',
#  'ahead',
#  'quantum',
#  'computing',
#  'expected',
#  'complement',
#  'rather',
#  'replace',
#  'classical',
#  'computing',
#  'Hybrid',
#  'system',
#  'quantum',
#  'processor',
#  'handle',
#  'specific',
#  'complex',
#  'task',
#  'classical',
#  'computer',
#  'manage',
#  'general',
#  'operation',
#  'likely',
#  'define',
#  'near',
#  'future',
#  'Continued',
#  'research',
#  'investment',
#  'collaboration',
#  'academia',
#  'industry',
#  'government',
#  'essential',
#  'unlock',
#  'full',
#  'potential',
#  'conclusion',
#  'quantum',
#  'computing',
#  'mark',
#  'new',
#  'era',
#  'computational',
#  'science',
#  'challenge',
#  'remain',
#  'ability',
#  'tackle',
#  'previously',
#  'unsolvable',
#  'problem',
#  'could',
#  'reshape',
#  'industry',
#  'strengthen',
#  'scientific',
#  'discovery',
#  'redefine',
#  'computationally',
#  'possible']

# %%
from nltk import ngrams

# %%
uni_gram = list(ngrams(clean_data,1))

# %%
uni_gram
# Out:
# [('Quantum',),
#  ('Computing',),
#  ('Redefining',),
#  ('Limits',),
#  ('Computation',),
#  ('Quantum',),
#  ('computing',),
#  ('represents',),
#  ('fundamental',),
#  ('shift',),
#  ('problems',),
#  ('processed',),
#  ('solved',),
#  ('machines',),
#  ('Unlike',),
#  ('classical',),
#  ('computers',),
#  ('use',),
#  ('bits',),
#  ('exist',),
#  ('either',),
#  ('quantum',),
#  ('computers',),
#  ('use',),
#  ('quantum',),
#  ('bits',),
#  ('qubits',),
#  ('Qubits',),
#  ('leverage',),
#  ('principles',),
#  ('quantum',),
#  ('superposition',),
#  ('perform',),
#  ('computations',),
#  ('ways',),
#  ('impossible',),
#  ('traditional',),
#  ('systems',),
#  ('unique',),
#  ('capability',),
#  ('positions',),
#  ('quantum',),
#  ('computing',),
#  ('breakthrough',),
#  ('technology',),
#  ('potential',),
#  ('solve',),
#  ('problems',),
#  ('far',),
#  ('beyond',),
#  ('reach',),
#  ('today',),
#  ('fastest',),
#  ('supercomputers',),
#  ('heart',),
#  ('quantum',),
#  ('computing',),
#  ('superposition',),
#  ('allows',),
#  ('qubit',),
#  ('exist',),
#  ('multiple',),
#  ('states',),
#  ('simultaneously',),
#  ('means',),
#  ('quantum',),
#  ('computer',),
#  ('explore',),
#  ('many',),
#  ('possible',),
#  ('solutions',),
#  ('time',),
#  ('rather',),
#  ('checking',),
#  ('one',),
#  ('one',),
#  ('Entanglement',),
#  ('enhances',),
#  ('power',),
#  ('linking',),
#  ('qubits',),
#  ('state',),
#  ('one',),
#  ('instantly',),
#  ('influences',),
#  ('another',),
#  ('even',),
#  ('across',),
#  ('distance',),
#  ('Together',),
#  ('properties',),
#  ('enable',),
#  ('massive',),
#  ('parallelism',),
#  ('exponential',),
#  ('speedups',),
#  ('specific',),
#  ('classes',),
#  ('problems',),
#  ('potential',),
#  ('applications',),
#  ('quantum',),
#  ('computing',),
#  ('transformative',),
#  ('cryptography',),
#  ('quantum',),
#  ('computers',),
#  ('could',),
#  ('break',),
#  ('widely',),
#  ('used',),
#  ('encryption',),
#  ('methods',),
#  ('prompting',),
#  ('development',),
#  ('security',),
#  ('systems',),
#  ('chemistry',),
#  ('materials',),
#  ('science',),
#  ('simulate',),
#  ('molecular',),
#  ('interactions',),
#  ('high',),
#  ('precision',),
#  ('accelerating',),
#  ('drug',),
#  ('discovery',),
#  ('creation',),
#  ('advanced',),
#  ('materials',),
#  ('Optimization',),
#  ('problems',),
#  ('logistics',),
#  ('finance',),
#  ('supply',),
#  ('complex',),
#  ('classical',),
#  ('approached',),
#  ('efficiently',),
#  ('quantum',),
#  ('algorithms',),
#  ('Despite',),
#  ('promise',),
#  ('quantum',),
#  ('computing',),
#  ('still',),
#  ('early',),
#  ('stage',),
#  ('Qubits',),
#  ('extremely',),
#  ('sensitive',),
#  ('environmental',),
#  ('noise',),
#  ('leading',),
#  ('errors',),
#  ('instability',),
#  ('Building',),
#  ('reliable',),
#  ('quantum',),
#  ('systems',),
#  ('requires',),
#  ('advanced',),
#  ('error',),
#  ('correction',),
#  ('precise',),
#  ('control',),
#  ('mechanisms',),
#  ('significant',),
#  ('engineering',),
#  ('breakthroughs',),
#  ('result',),
#  ('current',),
#  ('quantum',),
#  ('computers',),
#  ('experimental',),
#  ('limited',),
#  ('practical',),
#  ('use',),
#  ('Looking',),
#  ('ahead',),
#  ('quantum',),
#  ('computing',),
#  ('expected',),
#  ('complement',),
#  ('rather',),
#  ('replace',),
#  ('classical',),
#  ('computing',),
#  ('Hybrid',),
#  ('systems',),
#  ('quantum',),
#  ('processors',),
#  ('handle',),
#  ('specific',),
#  ('complex',),
#  ('tasks',),
#  ('classical',),
#  ('computers',),
#  ('manage',),
#  ('general',),
#  ('operations',),
#  ('likely',),
#  ('define',),
#  ('near',),
#  ('future',),
#  ('Continued',),
#  ('research',),
#  ('investment',),
#  ('collaboration',),
#  ('academia',),
#  ('industry',),
#  ('governments',),
#  ('essential',),
#  ('unlock',),
#  ('full',),
#  ('potential',),
#  ('conclusion',),
#  ('quantum',),
#  ('computing',),
#  ('marks',),
#  ('new',),
#  ('era',),
#  ('computational',),
#  ('science',),
#  ('challenges',),
#  ('remain',),
#  ('ability',),
#  ('tackle',),
#  ('previously',),
#  ('unsolvable',),
#  ('problems',),
#  ('could',),
#  ('reshape',),
#  ('industries',),
#  ('strengthen',),
#  ('scientific',),
#  ('discovery',),
#  ('redefine',),
#  ('computationally',),
#  ('possible',)]

# %%
bi_gram = list(ngrams(clean_data,2))

# %%
bi_gram
# Out:
# [('Quantum', 'Computing'),
#  ('Computing', 'Redefining'),
#  ('Redefining', 'Limits'),
#  ('Limits', 'Computation'),
#  ('Computation', 'Quantum'),
#  ('Quantum', 'computing'),
#  ('computing', 'represents'),
#  ('represents', 'fundamental'),
#  ('fundamental', 'shift'),
#  ('shift', 'problems'),
#  ('problems', 'processed'),
#  ('processed', 'solved'),
#  ('solved', 'machines'),
#  ('machines', 'Unlike'),
#  ('Unlike', 'classical'),
#  ('classical', 'computers'),
#  ('computers', 'use'),
#  ('use', 'bits'),
#  ('bits', 'exist'),
#  ('exist', 'either'),
#  ('either', 'quantum'),
#  ('quantum', 'computers'),
#  ('computers', 'use'),
#  ('use', 'quantum'),
#  ('quantum', 'bits'),
#  ('bits', 'qubits'),
#  ('qubits', 'Qubits'),
#  ('Qubits', 'leverage'),
#  ('leverage', 'principles'),
#  ('principles', 'quantum'),
#  ('quantum', 'superposition'),
#  ('superposition', 'perform'),
#  ('perform', 'computations'),
#  ('computations', 'ways'),
#  ('ways', 'impossible'),
#  ('impossible', 'traditional'),
#  ('traditional', 'systems'),
#  ('systems', 'unique'),
#  ('unique', 'capability'),
#  ('capability', 'positions'),
#  ('positions', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'breakthrough'),
#  ('breakthrough', 'technology'),
#  ('technology', 'potential'),
#  ('potential', 'solve'),
#  ('solve', 'problems'),
#  ('problems', 'far'),
#  ('far', 'beyond'),
#  ('beyond', 'reach'),
#  ('reach', 'today'),
#  ('today', 'fastest'),
#  ('fastest', 'supercomputers'),
#  ('supercomputers', 'heart'),
#  ('heart', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'superposition'),
#  ('superposition', 'allows'),
#  ('allows', 'qubit'),
#  ('qubit', 'exist'),
#  ('exist', 'multiple'),
#  ('multiple', 'states'),
#  ('states', 'simultaneously'),
#  ('simultaneously', 'means'),
#  ('means', 'quantum'),
#  ('quantum', 'computer'),
#  ('computer', 'explore'),
#  ('explore', 'many'),
#  ('many', 'possible'),
#  ('possible', 'solutions'),
#  ('solutions', 'time'),
#  ('time', 'rather'),
#  ('rather', 'checking'),
#  ('checking', 'one'),
#  ('one', 'one'),
#  ('one', 'Entanglement'),
#  ('Entanglement', 'enhances'),
#  ('enhances', 'power'),
#  ('power', 'linking'),
#  ('linking', 'qubits'),
#  ('qubits', 'state'),
#  ('state', 'one'),
#  ('one', 'instantly'),
#  ('instantly', 'influences'),
#  ('influences', 'another'),
#  ('another', 'even'),
#  ('even', 'across'),
#  ('across', 'distance'),
#  ('distance', 'Together'),
#  ('Together', 'properties'),
#  ('properties', 'enable'),
#  ('enable', 'massive'),
#  ('massive', 'parallelism'),
#  ('parallelism', 'exponential'),
#  ('exponential', 'speedups'),
#  ('speedups', 'specific'),
#  ('specific', 'classes'),
#  ('classes', 'problems'),
#  ('problems', 'potential'),
#  ('potential', 'applications'),
#  ('applications', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'transformative'),
#  ('transformative', 'cryptography'),
#  ('cryptography', 'quantum'),
#  ('quantum', 'computers'),
#  ('computers', 'could'),
#  ('could', 'break'),
#  ('break', 'widely'),
#  ('widely', 'used'),
#  ('used', 'encryption'),
#  ('encryption', 'methods'),
#  ('methods', 'prompting'),
#  ('prompting', 'development'),
#  ('development', 'security'),
#  ('security', 'systems'),
#  ('systems', 'chemistry'),
#  ('chemistry', 'materials'),
#  ('materials', 'science'),
#  ('science', 'simulate'),
#  ('simulate', 'molecular'),
#  ('molecular', 'interactions'),
#  ('interactions', 'high'),
#  ('high', 'precision'),
#  ('precision', 'accelerating'),
#  ('accelerating', 'drug'),
#  ('drug', 'discovery'),
#  ('discovery', 'creation'),
#  ('creation', 'advanced'),
#  ('advanced', 'materials'),
#  ('materials', 'Optimization'),
#  ('Optimization', 'problems'),
#  ('problems', 'logistics'),
#  ('logistics', 'finance'),
#  ('finance', 'supply'),
#  ('supply', 'complex'),
#  ('complex', 'classical'),
#  ('classical', 'approached'),
#  ('approached', 'efficiently'),
#  ('efficiently', 'quantum'),
#  ('quantum', 'algorithms'),
#  ('algorithms', 'Despite'),
#  ('Despite', 'promise'),
#  ('promise', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'still'),
#  ('still', 'early'),
#  ('early', 'stage'),
#  ('stage', 'Qubits'),
#  ('Qubits', 'extremely'),
#  ('extremely', 'sensitive'),
#  ('sensitive', 'environmental'),
#  ('environmental', 'noise'),
#  ('noise', 'leading'),
#  ('leading', 'errors'),
#  ('errors', 'instability'),
#  ('instability', 'Building'),
#  ('Building', 'reliable'),
#  ('reliable', 'quantum'),
#  ('quantum', 'systems'),
#  ('systems', 'requires'),
#  ('requires', 'advanced'),
#  ('advanced', 'error'),
#  ('error', 'correction'),
#  ('correction', 'precise'),
#  ('precise', 'control'),
#  ('control', 'mechanisms'),
#  ('mechanisms', 'significant'),
#  ('significant', 'engineering'),
#  ('engineering', 'breakthroughs'),
#  ('breakthroughs', 'result'),
#  ('result', 'current'),
#  ('current', 'quantum'),
#  ('quantum', 'computers'),
#  ('computers', 'experimental'),
#  ('experimental', 'limited'),
#  ('limited', 'practical'),
#  ('practical', 'use'),
#  ('use', 'Looking'),
#  ('Looking', 'ahead'),
#  ('ahead', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'expected'),
#  ('expected', 'complement'),
#  ('complement', 'rather'),
#  ('rather', 'replace'),
#  ('replace', 'classical'),
#  ('classical', 'computing'),
#  ('computing', 'Hybrid'),
#  ('Hybrid', 'systems'),
#  ('systems', 'quantum'),
#  ('quantum', 'processors'),
#  ('processors', 'handle'),
#  ('handle', 'specific'),
#  ('specific', 'complex'),
#  ('complex', 'tasks'),
#  ('tasks', 'classical'),
#  ('classical', 'computers'),
#  ('computers', 'manage'),
#  ('manage', 'general'),
#  ('general', 'operations'),
#  ('operations', 'likely'),
#  ('likely', 'define'),
#  ('define', 'near'),
#  ('near', 'future'),
#  ('future', 'Continued'),
#  ('Continued', 'research'),
#  ('research', 'investment'),
#  ('investment', 'collaboration'),
#  ('collaboration', 'academia'),
#  ('academia', 'industry'),
#  ('industry', 'governments'),
#  ('governments', 'essential'),
#  ('essential', 'unlock'),
#  ('unlock', 'full'),
#  ('full', 'potential'),
#  ('potential', 'conclusion'),
#  ('conclusion', 'quantum'),
#  ('quantum', 'computing'),
#  ('computing', 'marks'),
#  ('marks', 'new'),
#  ('new', 'era'),
#  ('era', 'computational'),
#  ('computational', 'science'),
#  ('science', 'challenges'),
#  ('challenges', 'remain'),
#  ('remain', 'ability'),
#  ('ability', 'tackle'),
#  ('tackle', 'previously'),
#  ('previously', 'unsolvable'),
#  ('unsolvable', 'problems'),
#  ('problems', 'could'),
#  ('could', 'reshape'),
#  ('reshape', 'industries'),
#  ('industries', 'strengthen'),
#  ('strengthen', 'scientific'),
#  ('scientific', 'discovery'),
#  ('discovery', 'redefine'),
#  ('redefine', 'computationally'),
#  ('computationally', 'possible')]

# %%
tri_gram = list(ngrams(clean_data,3))

# %%
tri_gram
# Out:
# [('Quantum', 'Computing', 'Redefining'),
#  ('Computing', 'Redefining', 'Limits'),
#  ('Redefining', 'Limits', 'Computation'),
#  ('Limits', 'Computation', 'Quantum'),
#  ('Computation', 'Quantum', 'computing'),
#  ('Quantum', 'computing', 'represents'),
#  ('computing', 'represents', 'fundamental'),
#  ('represents', 'fundamental', 'shift'),
#  ('fundamental', 'shift', 'problems'),
#  ('shift', 'problems', 'processed'),
#  ('problems', 'processed', 'solved'),
#  ('processed', 'solved', 'machines'),
#  ('solved', 'machines', 'Unlike'),
#  ('machines', 'Unlike', 'classical'),
#  ('Unlike', 'classical', 'computers'),
#  ('classical', 'computers', 'use'),
#  ('computers', 'use', 'bits'),
#  ('use', 'bits', 'exist'),
#  ('bits', 'exist', 'either'),
#  ('exist', 'either', 'quantum'),
#  ('either', 'quantum', 'computers'),
#  ('quantum', 'computers', 'use'),
#  ('computers', 'use', 'quantum'),
#  ('use', 'quantum', 'bits'),
#  ('quantum', 'bits', 'qubits'),
#  ('bits', 'qubits', 'Qubits'),
#  ('qubits', 'Qubits', 'leverage'),
#  ('Qubits', 'leverage', 'principles'),
#  ('leverage', 'principles', 'quantum'),
#  ('principles', 'quantum', 'superposition'),
#  ('quantum', 'superposition', 'perform'),
#  ('superposition', 'perform', 'computations'),
#  ('perform', 'computations', 'ways'),
#  ('computations', 'ways', 'impossible'),
#  ('ways', 'impossible', 'traditional'),
#  ('impossible', 'traditional', 'systems'),
#  ('traditional', 'systems', 'unique'),
#  ('systems', 'unique', 'capability'),
#  ('unique', 'capability', 'positions'),
#  ('capability', 'positions', 'quantum'),
#  ('positions', 'quantum', 'computing'),
#  ('quantum', 'computing', 'breakthrough'),
#  ('computing', 'breakthrough', 'technology'),
#  ('breakthrough', 'technology', 'potential'),
#  ('technology', 'potential', 'solve'),
#  ('potential', 'solve', 'problems'),
#  ('solve', 'problems', 'far'),
#  ('problems', 'far', 'beyond'),
#  ('far', 'beyond', 'reach'),
#  ('beyond', 'reach', 'today'),
#  ('reach', 'today', 'fastest'),
#  ('today', 'fastest', 'supercomputers'),
#  ('fastest', 'supercomputers', 'heart'),
#  ('supercomputers', 'heart', 'quantum'),
#  ('heart', 'quantum', 'computing'),
#  ('quantum', 'computing', 'superposition'),
#  ('computing', 'superposition', 'allows'),
#  ('superposition', 'allows', 'qubit'),
#  ('allows', 'qubit', 'exist'),
#  ('qubit', 'exist', 'multiple'),
#  ('exist', 'multiple', 'states'),
#  ('multiple', 'states', 'simultaneously'),
#  ('states', 'simultaneously', 'means'),
#  ('simultaneously', 'means', 'quantum'),
#  ('means', 'quantum', 'computer'),
#  ('quantum', 'computer', 'explore'),
#  ('computer', 'explore', 'many'),
#  ('explore', 'many', 'possible'),
#  ('many', 'possible', 'solutions'),
#  ('possible', 'solutions', 'time'),
#  ('solutions', 'time', 'rather'),
#  ('time', 'rather', 'checking'),
#  ('rather', 'checking', 'one'),
#  ('checking', 'one', 'one'),
#  ('one', 'one', 'Entanglement'),
#  ('one', 'Entanglement', 'enhances'),
#  ('Entanglement', 'enhances', 'power'),
#  ('enhances', 'power', 'linking'),
#  ('power', 'linking', 'qubits'),
#  ('linking', 'qubits', 'state'),
#  ('qubits', 'state', 'one'),
#  ('state', 'one', 'instantly'),
#  ('one', 'instantly', 'influences'),
#  ('instantly', 'influences', 'another'),
#  ('influences', 'another', 'even'),
#  ('another', 'even', 'across'),
#  ('even', 'across', 'distance'),
#  ('across', 'distance', 'Together'),
#  ('distance', 'Together', 'properties'),
#  ('Together', 'properties', 'enable'),
#  ('properties', 'enable', 'massive'),
#  ('enable', 'massive', 'parallelism'),
#  ('massive', 'parallelism', 'exponential'),
#  ('parallelism', 'exponential', 'speedups'),
#  ('exponential', 'speedups', 'specific'),
#  ('speedups', 'specific', 'classes'),
#  ('specific', 'classes', 'problems'),
#  ('classes', 'problems', 'potential'),
#  ('problems', 'potential', 'applications'),
#  ('potential', 'applications', 'quantum'),
#  ('applications', 'quantum', 'computing'),
#  ('quantum', 'computing', 'transformative'),
#  ('computing', 'transformative', 'cryptography'),
#  ('transformative', 'cryptography', 'quantum'),
#  ('cryptography', 'quantum', 'computers'),
#  ('quantum', 'computers', 'could'),
#  ('computers', 'could', 'break'),
#  ('could', 'break', 'widely'),
#  ('break', 'widely', 'used'),
#  ('widely', 'used', 'encryption'),
#  ('used', 'encryption', 'methods'),
#  ('encryption', 'methods', 'prompting'),
#  ('methods', 'prompting', 'development'),
#  ('prompting', 'development', 'security'),
#  ('development', 'security', 'systems'),
#  ('security', 'systems', 'chemistry'),
#  ('systems', 'chemistry', 'materials'),
#  ('chemistry', 'materials', 'science'),
#  ('materials', 'science', 'simulate'),
#  ('science', 'simulate', 'molecular'),
#  ('simulate', 'molecular', 'interactions'),
#  ('molecular', 'interactions', 'high'),
#  ('interactions', 'high', 'precision'),
#  ('high', 'precision', 'accelerating'),
#  ('precision', 'accelerating', 'drug'),
#  ('accelerating', 'drug', 'discovery'),
#  ('drug', 'discovery', 'creation'),
#  ('discovery', 'creation', 'advanced'),
#  ('creation', 'advanced', 'materials'),
#  ('advanced', 'materials', 'Optimization'),
#  ('materials', 'Optimization', 'problems'),
#  ('Optimization', 'problems', 'logistics'),
#  ('problems', 'logistics', 'finance'),
#  ('logistics', 'finance', 'supply'),
#  ('finance', 'supply', 'complex'),
#  ('supply', 'complex', 'classical'),
#  ('complex', 'classical', 'approached'),
#  ('classical', 'approached', 'efficiently'),
#  ('approached', 'efficiently', 'quantum'),
#  ('efficiently', 'quantum', 'algorithms'),
#  ('quantum', 'algorithms', 'Despite'),
#  ('algorithms', 'Despite', 'promise'),
#  ('Despite', 'promise', 'quantum'),
#  ('promise', 'quantum', 'computing'),
#  ('quantum', 'computing', 'still'),
#  ('computing', 'still', 'early'),
#  ('still', 'early', 'stage'),
#  ('early', 'stage', 'Qubits'),
#  ('stage', 'Qubits', 'extremely'),
#  ('Qubits', 'extremely', 'sensitive'),
#  ('extremely', 'sensitive', 'environmental'),
#  ('sensitive', 'environmental', 'noise'),
#  ('environmental', 'noise', 'leading'),
#  ('noise', 'leading', 'errors'),
#  ('leading', 'errors', 'instability'),
#  ('errors', 'instability', 'Building'),
#  ('instability', 'Building', 'reliable'),
#  ('Building', 'reliable', 'quantum'),
#  ('reliable', 'quantum', 'systems'),
#  ('quantum', 'systems', 'requires'),
#  ('systems', 'requires', 'advanced'),
#  ('requires', 'advanced', 'error'),
#  ('advanced', 'error', 'correction'),
#  ('error', 'correction', 'precise'),
#  ('correction', 'precise', 'control'),
#  ('precise', 'control', 'mechanisms'),
#  ('control', 'mechanisms', 'significant'),
#  ('mechanisms', 'significant', 'engineering'),
#  ('significant', 'engineering', 'breakthroughs'),
#  ('engineering', 'breakthroughs', 'result'),
#  ('breakthroughs', 'result', 'current'),
#  ('result', 'current', 'quantum'),
#  ('current', 'quantum', 'computers'),
#  ('quantum', 'computers', 'experimental'),
#  ('computers', 'experimental', 'limited'),
#  ('experimental', 'limited', 'practical'),
#  ('limited', 'practical', 'use'),
#  ('practical', 'use', 'Looking'),
#  ('use', 'Looking', 'ahead'),
#  ('Looking', 'ahead', 'quantum'),
#  ('ahead', 'quantum', 'computing'),
#  ('quantum', 'computing', 'expected'),
#  ('computing', 'expected', 'complement'),
#  ('expected', 'complement', 'rather'),
#  ('complement', 'rather', 'replace'),
#  ('rather', 'replace', 'classical'),
#  ('replace', 'classical', 'computing'),
#  ('classical', 'computing', 'Hybrid'),
#  ('computing', 'Hybrid', 'systems'),
#  ('Hybrid', 'systems', 'quantum'),
#  ('systems', 'quantum', 'processors'),
#  ('quantum', 'processors', 'handle'),
#  ('processors', 'handle', 'specific'),
#  ('handle', 'specific', 'complex'),
#  ('specific', 'complex', 'tasks'),
#  ('complex', 'tasks', 'classical'),
#  ('tasks', 'classical', 'computers'),
#  ('classical', 'computers', 'manage'),
#  ('computers', 'manage', 'general'),
#  ('manage', 'general', 'operations'),
#  ('general', 'operations', 'likely'),
#  ('operations', 'likely', 'define'),
#  ('likely', 'define', 'near'),
#  ('define', 'near', 'future'),
#  ('near', 'future', 'Continued'),
#  ('future', 'Continued', 'research'),
#  ('Continued', 'research', 'investment'),
#  ('research', 'investment', 'collaboration'),
#  ('investment', 'collaboration', 'academia'),
#  ('collaboration', 'academia', 'industry'),
#  ('academia', 'industry', 'governments'),
#  ('industry', 'governments', 'essential'),
#  ('governments', 'essential', 'unlock'),
#  ('essential', 'unlock', 'full'),
#  ('unlock', 'full', 'potential'),
#  ('full', 'potential', 'conclusion'),
#  ('potential', 'conclusion', 'quantum'),
#  ('conclusion', 'quantum', 'computing'),
#  ('quantum', 'computing', 'marks'),
#  ('computing', 'marks', 'new'),
#  ('marks', 'new', 'era'),
#  ('new', 'era', 'computational'),
#  ('era', 'computational', 'science'),
#  ('computational', 'science', 'challenges'),
#  ('science', 'challenges', 'remain'),
#  ('challenges', 'remain', 'ability'),
#  ('remain', 'ability', 'tackle'),
#  ('ability', 'tackle', 'previously'),
#  ('tackle', 'previously', 'unsolvable'),
#  ('previously', 'unsolvable', 'problems'),
#  ('unsolvable', 'problems', 'could'),
#  ('problems', 'could', 'reshape'),
#  ('could', 'reshape', 'industries'),
#  ('reshape', 'industries', 'strengthen'),
#  ('industries', 'strengthen', 'scientific'),
#  ('strengthen', 'scientific', 'discovery'),
#  ('scientific', 'discovery', 'redefine'),
#  ('discovery', 'redefine', 'computationally'),
#  ('redefine', 'computationally', 'possible')]
