# %% [markdown]
# # Conditional statements

# %% [markdown]
# ##  IF STATEMENT

# %%
age=int(input("Enter the age:"))
p_age=10
if(age<10):
    print("You can Permitted")

# %% [markdown]
# ## IF ELSE STATEMENT

# %%
age=int(input("Enter the age:"))
p_age=10
if(age<10):
    print("You can Permitted")
else:
    print("You cannot be permitted")

# %%
age=int(input("Enter the age:"))
p_age=10
if(age<p_age):
    print("You can Permitted")
else:
    print(f"you are {age} years old so You cannot be permitted")

# %% [markdown]
# ## ELIF STATEMENT

# %%
a=int(input("Enter the first num:"))
b=int(input("Enter the second num:"))
if(b>a):
    print("b is greater")
elif(b<a):
    print("a is lesser")
else:
    print("b is equal to a")

# %%
a=int(input("Enter the first num:"))
b=int(input("Enter the second num:"))
if(b>a):
    print("b is greater than a")
elif(b<a):
    print("a is lesser than b")
else:
    print("b is equal to a")

# %% [markdown]
# ## Nested if else statements   AND Given as assignment

# %%
grade=int(input("Enter the grade:"))
pratical_grade=int(input("Enter the pratical grade:"))
record_marks=int(input("Enter your record:"))
if(grade>=8):
    print("pass")
    if(pratical_grade>=70):
        print("Topper")
        if(record_marks>4):
            print("Distinction")
        else:
            print("No Distinction")
    else:
        print("Looser")
else:
    print("Fail")

# %% [markdown]
# ## while loop

# %%
i=1
while(i<6):
    print(i)
    i+=1

# %% [markdown]
# ## FOR

# %%
a=[20,30,40,50,60,70]
for i in a:
    print(i+2)

# %%
a=[20,30,40,50,60,70]
for i in a:
    print(i+2)
    print("hello")

# %%
fruits=['apple','banana', 'grapes']
for x in fruits:
    print(x)

# %%
i=0
while i<6:
    i+=1
    if i==3:
        continue
    print(i)

# %%
i=0

while i<6:
    print(i)

    if i==15:
        break
    i+=1

# %%
i=0
while i<6:
    i+=1
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
def add(a,b):
    sum=a+b
    return sum

# %%
print("Hello")
# Out:
# Hello

# %%
print("Bye")
# Out:
# Bye

# %%
add(5,10)
# Out:
# 15

# %%
x=int(input("enter x value:"))
y=int(input("enter y value:"))
add(x,y)
# Out:
# enter x value: 15
# enter y value: 15
# 30
