# %% [markdown]
# #CHAPTER 1

# %%
print("Hello_World")
# Out:
# Hello_World

# %%
print("Hi Wecome to python programming")
# Out:
# Hi Wecome to python programming

# %%
a=10
print(a)
# Out:
# 10

# %%
_a=19
print(_a)
# Out:
# 19

# %%
$b=90
print($b)
# Out:
#   Cell In[9], line 1
#     $b=90
#     ^
# SyntaxError: invalid syntax

# %%
2a=40

# %%
2a

# %% [markdown]
# # CHAPTER 1

# %% [markdown]
# ## VARIABLES

# %%
print("Hello World!")

# %%
#Different IDE and Jupyter notebook explorations

# %%
a=19

# %%
print(a)
# Out:
# 19

# %%
#Spyder is used for deployment.

# %%
print("Hi welcome to chandrus programming")
# Out:
# Hi welcome to chandrus programming

# %%
a=100

# %%
print(a)
# Out:
# 100

# %%
$a=100
# Out:
#   Cell In[17], line 1
#     $a=100
#     ^
# SyntaxError: invalid syntax

# %%
# specials are not allowed

# %%
_a=20 #ubderscore is allowed

# %%
_a
# Out:
# 20

# %%
2a=20
# Out:
#   Cell In[21], line 1
#     2a=20
#     ^
# SyntaxError: invalid decimal literal

# %%
#Number are not allowed

# %%
a2=40

# %%
a2
# Out:
# 40

# %%
price=100

# %%
print(f'{price}$')
# Out:
# 100$

# %%
'''
DATA TYPE   = 1.basic data type, 2. Advanced data type
basic= int,float.complex,bool,string
advanced= set list tuple,dictionary

'''
# Out:
# '\nDATA TYPE   = 1.basic data type, 2. Advanced data type\nbasic= int,float.complex,bool,string\nadvanced= set list tuple,dictionary\n\n'

# %%
a=9

# %%
type(a)
# Out:
# int

# %%
b=9.5

# %%
type(b)
# Out:
# float

# %%
a<b
# Out:
# True

# %%
type(a<b)
# Out:
# bool

# %%
print('Hello world')    #single quote
# Out:
# Hello world

# %%
print("Johnson's is good boy")   #double quote
# Out:
# Johnson's is good boy

# %%
print('''"PIchai" your are amazing''')     #Triple quote
# Out:
# "PIchai" your are amazing

# %%
First_name='praveen'

# %%
Last_name='kumar'

# %%
First_name+ " " +Last_name
# Out:
# 'praveen kumar'

# %%
Full_name= First_name + " " + Last_name

# %%
Full_name
# Out:
# 'praveen kumar'

# %%
Full_name.upper()
# Out:
# 'PRAVEEN KUMAR'

# %%
Full_name.lower()
# Out:
# 'praveen kumar'
