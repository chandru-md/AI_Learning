# %% [markdown]
# # Day_04 STRING METHODS

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Endswith

# %%
s="Classes are going"
print(s.endswith("ing"))
# Out:
# True

# %%
s="Lectures is amazing"
print(s.endswith("amazing"))
# Out:
# True

# %%
s="Chandru is good"
print(s.endswith("goof"))
# Out:
# False

# %% [markdown]
# ## Startswith

# %%
x="Old is gold"
print(x.startswith("Old"))
# Out:
# True

# %%
x="Old is gold"
print(x.startswith("Ol"))
# Out:
# True

# %% [markdown]
# ## Lower

# %%
n="Hello World"
print(n.lower())
# Out:
# hello world

# %% [markdown]
# ## Upper

# %%
m="Hello world"
print(m.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# ## Strip

# %%
d="   Chandru is a Data Scientist   "
print(d.strip())
# Out:
# Chandru is a Data Scientist

# %% [markdown]
# ## Replace

# %%
e="Hello World"
print(e.replace("World","Trainer"))
# Out:
# Hello Trainer

# %% [markdown]
# ## Capitalize

# %%
s="chandru"
print(s.capitalize())
# Out:
# Chandru

# %% [markdown]
# ## Title

# %%
name="hello world"
print(name.title())
# Out:
# Hello World

# %% [markdown]
# ## Isalpha

# %%
g="Minister"
print(g.isalpha())
# Out:
# True

# %% [markdown]
# ## Isdigit

# %%
num="123456789"
print(num.isdigit())
# Out:
# True

# %% [markdown]
# ## Isalnum

# %%
deq="Chandru810019105019"
print(deq.isalnum())
# Out:
# True

# %% [markdown]
# ## Split

# %%
y="Chandru , kadhir , Naveen , Razeeth"
print(y.split(','))
# Out:
# ['Chandru ', ' kadhir ', ' Naveen ', ' Razeeth']

# %% [markdown]
# ## Join

# %%
frds=['Chandru','Kadhir','Naveen','Boominath']
print(','.join(frds))
# Out:
# Chandru,Kadhir,Naveen,Boominath
