# %%
import numpy as np

# %%
from scipy import stats

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # One sample T test

# %%
sample_data=np.array([85,86,77,42,50,82,90,75,72,70,80,45,55,68,92,41,54,63,82,88])

# %%
hypothesized_mean=75

# %%
t_stats,p_value=stats.ttest_1samp(sample_data,hypothesized_mean)
# Out:
# TtestResult(statistic=np.float64(-1.374002016325974), pvalue=np.float64(0.18543474680273658), df=np.int64(19))

# %%
t_stats,p_value=stats.ttest_1samp(sample_data,hypothesized_mean)

# %%
alpha=0.05

# %%
p_value
# Out:
# np.float64(0.18543474680273658)

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Fail to reject null hypothesis

# %%
# p_value is greater than alpha value so, we have to accept the null hypothesis

# %% [markdown]
# # one sample proportion test

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\chandrumd\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
hypo_prop=0.4
sample_size=200
n_success=100

# %%
z_stats,p_value=sm.stats.proportions_ztest(n_success,sample_size,hypo_prop)

# %%
p_value
# Out:
# np.float64(0.004677734981047275)

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject the null hypothesis

# %% [markdown]
# # Two sample T test

# %%
method_A_scores=np.array([90,75,80,45,68,52,98,76,71,95])

# %%
method_B_scores=np.array([90,80,60,78,55,85,94,84,71,87])

# %%
t_stats,p_values=stats.ttest_ind(method_A_scores,method_B_scores)

# %%
p_value
# Out:
# np.float64(0.004677734981047275)

# %%
t_stats
# Out:
# np.float64(-0.501036470367726)

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject the null hypothesis

# %% [markdown]
# # Two sample proportion test

# %%
n_samples_x=100
n_success_x=45
n_samples_y=120
n_success_y=30
z_stats,p_value=sm.stats.proportions_ztest([n_success_x,n_success_y],[n_samples_x,n_samples_y])

# %%
z_stats
# Out:
# np.float64(3.116142619904648)

# %%
p_value
# Out:
# np.float64(0.0018323362992630889)

# %%
alpha=0.05

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject the null hypothesis

# %% [markdown]
# # Paired T Test

# %%
import numpy as np

# %%
from scipy import stats

# %%
before_training=np.array([50,60,65,70,55,74,68,82,90,95])
after_training=np.array([80,75,78,98,55,65,88,64,84,68])

# %%
difference=after_training - before_training

# %%
difference
# Out:
# array([ 30,  15,  13,  28,   0,  -9,  20, -18,  -6, -27])

# %%
t_stats,p_value=stats.ttest_rel(after_training,before_training)

# %%
p_value
# Out:
# np.float64(0.47560044636292165)

# %%
alpha=0.05

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Fail to reject null hypothesis

# %% [markdown]
# # Anova Test (Analysis of variance)

# %% [markdown]
# ## One way anova

# %%
fertilizer_a=np.array([50,55,52,48,45,49])
fertilizer_b=np.array([55,59,56,46,48,50])
fertilizer_c=np.array([58,60,55,49,51,53])

# %%
stats.f_oneway(fertilizer_a,fertilizer_b,fertilizer_c)
# Out:
# F_onewayResult(statistic=np.float64(1.660617059891107), pvalue=np.float64(0.22311255505031893))

# %%
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Fail to reject null hypothesis

# %% [markdown]
# ## Two way anova

# %%
import pandas as pd

# %%
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols

# %%
data={"Gender":['Male','Male','Male','Male','Male','Male','Male','Male'],
     "Diet":['A','A','B','C','B','A','C','C'],
     "weight_loss":[4.5,6.5,3.5,1.0,2.5,2.9,8.5,5.5]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Gender Diet  weight_loss
# 0   Male    A          4.5
# 1   Male    A          6.5
# 2   Male    B          3.5
# 3   Male    C          1.0
# 4   Male    B          2.5
# 5   Male    A          2.9
# 6   Male    C          8.5
# 7   Male    C          5.5

# %%
formula="weight_loss~C(Gender)+C(Diet)+C(Gender):C(Diet)" #Linear model

# %%
model=ols(formula,df).fit()

# %%
anova_lm(model)
# Out:
#                     df     sum_sq   mean_sq         F    PR(>F)
# C(Gender)          0.0   0.000000       NaN       NaN       NaN
# C(Diet)            2.0   5.152083  2.576042  0.362755  0.712672
# C(Gender):C(Diet)  0.0   0.000000       NaN       NaN       NaN
# Residual           5.0  35.506667  7.101333       NaN       NaN

# %%
anova_res=anova_lm(model)

# %%
anova_res["PR(>F)"]
# Out:
# C(Gender)                 NaN
# C(Diet)              0.712672
# C(Gender):C(Diet)         NaN
# Residual                  NaN
# Name: PR(>F), dtype: float64

# %%
# ols=ordinary least square.
